# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import tqdm 
import sys
import os
sys.path.append('../')
os.chdir('../')
from src.utils.stat_functions import *

# %%
# S robustness all labs SSE loss
S_a1an = pickle.load(open('src/data/17-6-24/a1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/a1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi(S_a1an, title="NMI($S_i, S_{i+1}$) for all labs with SSE loss")
# Out:
# 100%|██████████| 9/9 [00:41<00:00,  4.62s/it]

# %%
# S, sleepstage all labs SSE loss
S_a1an = pickle.load(open('src/data/17-6-24/a1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/a1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi_one_hot_sleep([S_a1an], [y_a1an], title="NMI(S, sleepstage) for all labs with SSE loss", loc='center right')
# Out:
# 100%|██████████| 9/9 [00:28<00:00,  3.11s/it]
# c:\Users\August-PC\OneDrive - Danmarks Tekniske Universitet\School\4S\Project\sleepy_mice\src\utils\stat_functions.py:472: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color='red', label=f'{lab_name[lab]} permuted', linestyle='--')

# %%
# S, labs all labs SSE loss
S_a1an = pickle.load(open('src/data/17-6-24/a1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/a1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi_one_hot_labs(S_a1an, y2_a1an, title="NMI(S, labs) for all labs with SSE loss")
# Out:
# 9it [00:30,  3.35s/it]
# c:\Users\August-PC\OneDrive - Danmarks Tekniske Universitet\School\4S\Project\sleepy_mice\src\utils\stat_functions.py:528: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[0], label='Permuted', linestyle='--')

# %%
# S robustness for all labs with log loss
S_a1al = pickle.load(open('src/data/17-6-24/a1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/a1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi(S_a1al, title="NMI($S_i$,$S_{i+1}$) for all labs with log loss")
# Out:
# 100%|██████████| 9/9 [00:39<00:00,  4.34s/it]

# %%
# S, sleepstage all labs with log loss
S_a1al = pickle.load(open('src/data/17-6-24/a1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/a1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi_one_hot_sleep([S_a1al], [y_a1al], title="NMI(S, sleepstage) for all labs with log loss")
# Out:
# 100%|██████████| 9/9 [00:30<00:00,  3.34s/it]
# c:\Users\August-PC\OneDrive - Danmarks Tekniske Universitet\School\4S\Project\sleepy_mice\src\utils\stat_functions.py:472: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color='red', label=f'{lab_name[lab]} permuted', linestyle='--')

# %%
# S, labs all labs with log loss
S_a1al = pickle.load(open('src/data/17-6-24/a1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/a1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi_one_hot_labs(S_a1al, y2_a1al, title="NMI(S, labs) for all labs with log loss")
# Out:
# 9it [00:29,  3.24s/it]
# c:\Users\August-PC\OneDrive - Danmarks Tekniske Universitet\School\4S\Project\sleepy_mice\src\utils\stat_functions.py:528: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[0], label='Permuted', linestyle='--')
