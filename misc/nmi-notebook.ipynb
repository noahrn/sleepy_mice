# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import tqdm 
import sys
import os
sys.path.append('../')
os.chdir('../')
from src.utils.stat_functions import *

# %%
S_a1al = pickle.load(open('src/data/17-6-24/all1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/all1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi(S_a1al, title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 100%|██████████| 9/9 [00:29<00:00,  3.27s/it]

# %%
S_a1al = pickle.load(open('src/data/17-6-24/all1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/all1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi_one_hot_labs(S_a1al, y2_a1al, title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 9it [00:21,  2.35s/it]
# c:\Users\augus\OneDrive\DTU\Fagprojekt\sleepy_mice\misc\..\src\utils\stat_functions.py:528: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[0], label='Permuted', linestyle='--')

# %%
S_a1al = pickle.load(open('src/data/17-6-24/all1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/all1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi_one_hot_sleep([S_a1al], [y_a1al], title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 100%|██████████| 9/9 [00:21<00:00,  2.39s/it]
# c:\Users\augus\OneDrive\DTU\Fagprojekt\sleepy_mice\src\utils\stat_functions.py:472: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[lab], label=f'All labs permuted', linestyle='--')

# %%
S_a1an = pickle.load(open('src/data/17-6-24/all1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/all1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi(S_a1an, title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 100%|██████████| 9/9 [00:33<00:00,  3.71s/it]

# %%
S_a1an = pickle.load(open('src/data/17-6-24/all1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/all1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi_one_hot_labs(S_a1an, y2_a1an, title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 9it [00:20,  2.25s/it]
# c:\Users\augus\OneDrive\DTU\Fagprojekt\sleepy_mice\misc\..\src\utils\stat_functions.py:528: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[0], label='Permuted', linestyle='--')

# %%
S_a1an = pickle.load(open('src/data/17-6-24/all1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/all1an/info_list_20240617-170732.pkl', 'rb'))
plot_comparison_nmi_one_hot_sleep([S_a1an], [y_a1an], title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 100%|██████████| 9/9 [00:21<00:00,  2.37s/it]
# c:\Users\augus\OneDrive\DTU\Fagprojekt\sleepy_mice\src\utils\stat_functions.py:472: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(positions, np.mean(all_permuted_scores, axis=1), 'o-', color=colors[lab], label=f'All labs permuted', linestyle='--')
