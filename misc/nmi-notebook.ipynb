# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import tqdm 
import sys
import os
sys.path.append('../')
from src.utils.stat_functions import *

# %%
S_a1al = pickle.load(open('data/17-6-24/all1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('data/17-6-24/all1al/info_list_20240617-203201.pkl', 'rb'))
plot_comparison_nmi(S_a1al, title="Comparison of NMI scores for all labs concatenated with log loss: Original vs Permuted")
# Out:
# 100%|██████████| 9/9 [00:28<00:00,  3.21s/it]
