# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import tqdm 
import sys
import os
sys.path.append('../')
os.chdir('../')
from src.utils.stat_functions import *

# %%
# a1an
S_a1an = pickle.load(open('src/data/17-6-24/15_a1an/S_lists_20240617-170732.pkl', 'rb'))
X_a1an, y_a1an, y2_a1an = pickle.load(open('src/data/17-6-24/15_a1an/info_list_20240617-170732.pkl', 'rb'))

# a1al
S_a1al = pickle.load(open('src/data/17-6-24/17_a1al/S_lists_20240617-203201.pkl', 'rb'))
X_a1al, y_a1al, y2_a1al = pickle.load(open('src/data/17-6-24/17_a1al/info_list_20240617-203201.pkl', 'rb'))

# %% [markdown]
# # A1AN

# %%
# S robustness all labs SSE loss
plot_comparison_nmi(S_a1an, title="NMI($S^{(r)}, S^{(r')}$) for all labs with SSE loss")
plt.savefig('src/plot_data/a1an/robustness_all_labs_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:23<00:00,  2.62s/it]

# %%
# S, sleepstage all labs SSE loss
plot_comparison_nmi_one_hot_sleep([S_a1an], [y_a1an], title="NMI(S, sleepstage) for all labs with SSE loss", loc='center right')
plt.savefig('src/plot_data/a1an/S_sleepstage_all_labs_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.46it/s]

# %%
# S, labs all labs SSE loss
plot_comparison_nmi_one_hot_labs(S_a1an, y2_a1an, title="NMI(S, labs) for all labs with SSE loss")
plt.savefig('src/plot_data/a1an/S_labs_all_labs_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.66it/s]

# %% [markdown]
# # A1AL

# %%
# S robustness for all labs with log loss
plot_comparison_nmi(S_a1al, title="NMI($S^{(r)}, S^{(r')}$) for all labs with log loss")
plt.savefig('src/plot_data/a1al/robustness_all_labs_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:19<00:00,  2.15s/it]

# %%
# S, sleepstage all labs with log loss
plot_comparison_nmi_one_hot_sleep([S_a1al], [y_a1al], title="NMI(S, sleepstage) for all labs with log loss")
plt.savefig('src/plot_data/a1al/S_sleepstage_all_labs_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.42it/s]

# %%
# S, labs all labs with log loss
plot_comparison_nmi_one_hot_labs(S_a1al, y2_a1al, title="NMI(S, labs) for all labs with log loss")
plt.savefig('src/plot_data/a1al/S_labs_all_labs_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.73it/s]

# %%
# 11an
S_11an = pickle.load(open('src/data/17-6-24/19_11an/S_lists_20240617-191948.pkl', 'rb'))
X_11an, y_11an, y2_11an = pickle.load(open('src/data/17-6-24/19_11an/info_list_20240617-191948.pkl', 'rb'))

# 11al
S_11al = pickle.load(open('src/data/17-6-24/21_11al/S_lists_20240617-194447.pkl', 'rb'))
X_11al, y_11al, y2_11al = pickle.load(open('src/data/17-6-24/21_11al/info_list_20240617-194447.pkl', 'rb'))

# %% [markdown]
# # 11AN

# %%
# S robustness lab1 with SSE loss
plot_comparison_nmi(S_11an, title="NMI($S^{(r)}, S^{(r')}$) for lab1 with SSE loss")
plt.savefig('src/plot_data/11an/robustness_lab1_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:08<00:00,  1.09it/s]

# %%
# S, sleepstage lab1 with SSE loss
plot_comparison_nmi_one_hot_sleep([S_11an], [y_11an], title="NMI(S, sleepstage) for lab1 with SSE loss", loc='center right')
plt.savefig('src/plot_data/11an/S_sleepstage_lab1_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  7.36it/s]

# %% [markdown]
# # 11AL

# %%
# S robustness lab1 with log loss
plot_comparison_nmi(S_11al, title="NMI($S^{(r)}, S^{(r')}$) for lab1 with log loss")
plt.savefig('src/plot_data/11al/robustness_lab1_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:05<00:00,  1.77it/s]

# %%
# S, sleepstage lab1 with log loss
plot_comparison_nmi_one_hot_sleep([S_11al], [y_11al], title="NMI(S, sleepstage) for lab1 with log loss")
plt.savefig('src/plot_data/11al/S_sleepstage_lab1_log_loss.svg', format='svg')
plt.show()
# Out:
# ...
# 100%|██████████| 9/9 [00:01<00:00,  6.89it/s]

# %% [markdown]
# # Lab 3

# %%
# 31an
S_31an = pickle.load(open('src/data/17-6-24/25_31an/S_lists_20240617-211347.pkl', 'rb'))
X_31an, y_31an, y2_31an = pickle.load(open('src/data/17-6-24/25_31an/info_list_20240617-211347.pkl', 'rb'))

# 31al
S_31al = pickle.load(open('src/data/17-6-24/31_31al/S_lists_20240619-170352.pkl', 'rb'))
X_31al, y_31al, y2_31al, _ = pickle.load(open('src/data/17-6-24/31_31al/info_list_20240619-170352.pkl', 'rb'))

# %% [markdown]
# # 31AN

# %%
# 31AN
# S robustness lab3 with SSE loss
plot_comparison_nmi(S_31an, title="NMI($S^{(r)}, S^{(r')}$) for lab3 with SSE loss")
plt.savefig('src/plot_data/31an/robustness_lab3_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  3.09it/s]

# %%
# 31AN
# S, sleepstage lab3 with SSE loss
plot_comparison_nmi_one_hot_sleep([S_31an], [y_31an], title="NMI(S, sleepstage) for lab3 with SSE loss", loc='center right')
plt.savefig('src/plot_data/31an/S_sleepstage_lab3_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  5.70it/s]

# %% [markdown]
# # 31AL

# %%
# 31AL
# S robustness lab3 with log loss
plot_comparison_nmi(S_31al, title="NMI($S^{(r)}, S^{(r')}$) for lab3 with log loss")
plt.savefig('src/plot_data/31al/robustness_lab3_log_loss.svg', format='svg')
plt.show()
# Out:
# ...
# 100%|██████████| 9/9 [00:02<00:00,  3.02it/s]

# %%
# 31AL
# S, sleepstage lab3 with log loss
plot_comparison_nmi_one_hot_sleep([S_31al], [y_31al], title="NMI(S, sleepstage) for lab3 with log loss", loc='upper left')
plt.savefig('src/plot_data/31al/S_sleepstage_lab3_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  6.15it/s]

# %% [markdown]
# # Narcoleptic

# %%
# 31an narc
S_31an_narc = pickle.load(open('src/data/22-6-24/fixed_narc_31an/S_lists_20240622-233950.pkl', 'rb'))
X_31an_narc, y_31an_narc, y2_31an_narc, y3_31an_narc, y4_31an_narc, loss_31an_narc = pickle.load(open('src/data/22-6-24/fixed_narc_31an/info_list_20240622-233950.pkl', 'rb'))

# 31al narc
S_31al_narc = pickle.load(open('src/data/22-6-24/fixed_narc_31al/S_lists_20240622-221035.pkl', 'rb'))
X_31al_narc, y_31al_narc, y2_31al_narc, y3_31al_narc, y4_31al_narc, loss_31al_narc = pickle.load(open('src/data/22-6-24/fixed_narc_31al/info_list_20240622-221035.pkl', 'rb'))

# %% [markdown]
# # 31AN narc

# %%
# S robustness lab3 narcolepsy with SSE loss
plot_comparison_nmi(S_31an_narc, title="NMI($S^{(r)}, S^{(r')}$) for lab3 narcolepsy with SSE loss")
plt.savefig('src/plot_data/nac_31an/robustness_lab3_narcolepsy_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:04<00:00,  1.84it/s]

# %%
# S, sleepstage lab3 narcolepsy with SSE loss
plot_comparison_nmi_one_hot_sleep([S_31an_narc], [y_31an_narc], title="NMI(S, sleepstage) for lab3 narcolepsy with SSE loss", loc='center right')
plt.savefig('src/plot_data/nac_31an/S_sleepstage_lab3_narcolepsy_SSE_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  3.75it/s]

# %% [markdown]
# # 31AL narc

# %%
# S robustness lab3 narcolepsy with log loss
plot_comparison_nmi(S_31al_narc, title="NMI($S^{(r)}, S^{(r')}$) for lab3 narcolepsy with log loss")
plt.savefig('src/plot_data/nac_31al/robustness_lab3_narcolepsy_log_loss.svg', format='svg')
plt.show()
# Out:
# 100%|██████████| 9/9 [00:04<00:00,  1.95it/s]

# %%
# S, sleepstage lab3 narcolepsy with log loss
plot_comparison_nmi_one_hot_sleep([S_31al_narc], [y_31al_narc], title="NMI(S, sleepstage) for lab3 narcolepsy with log loss")
plt.savefig('src/plot_data/nac_31al/S_sleepstage_lab3_narcolepsy_log_loss.svg', format='svg')
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  3.81it/s]
